# %%
import urllib.request
import cv2
import numpy as np
import os

# %%
def resize_image():
    img = cv2.imread(r"C:\Users\dell\Desktop\Hemant\Images\Ambulance1.jpg")
    resized_image = cv2.resize(img, (30, 60))
    cv2.imwrite(r"C:\Users\dell\Desktop\Hemant\Images\Ambulance1.jpg",resized_image)
def store_raw_images():
    neg_images_link = 'http://www.image-net.org/api/text/imagenet.synset.geturls?wnid=n02701002'   
    neg_image_urls = urllib.request.urlopen(neg_images_link).read().decode()
    pic_num = 1
    
    if not os.path.exists('neg'):
        os.makedirs('neg')
        
    for i in neg_image_urls.split('\n'):
        try:
            print(i)
            urllib.request.urlretrieve(i, "neg/"+str(pic_num)+".jpg")
            img = cv2.imread("neg/"+str(pic_num)+".jpg",cv2.IMREAD_GRAYSCALE)
            # should be larger than samples / pos pic (so we can place our image on it)
            resized_image = cv2.resize(img, (100, 100))
            cv2.imwrite("neg/"+str(pic_num)+".jpg",resized_image)
            pic_num += 1
            
        except Exception as e:
            print(str(e))

# %%
def find_uglies():
    match = False
    for file_type in ['neg']:
        for img in os.listdir(file_type):
            for ugly in os.listdir('uglies'):
                try:
                    current_image_path = str(file_type)+'/'+str(img)
                    ugly = cv2.imread('uglies/'+str(ugly))
                    question = cv2.imread(current_image_path)
                    if ugly.shape == question.shape and not(np.bitwise_xor(ugly,question).any()):
                        print('That is one ugly pic! Deleting!')
                        print(current_image_path)
                        os.remove(current_image_path)
                except Exception as e:
                    print(str(e))
def create_pos_n_neg():
    for file_type in ['neg']:        
        for img in os.listdir(file_type):
            if file_type == 'pos':
                line = file_type+'/'+img+' 1 0 0 50 50\n'
                with open('info.dat','a') as f:
                    f.write(line)
            elif file_type == 'neg':
                line = file_type+'/'+img+'\n'
                with open('bg.txt','a') as f:
                    f.write(line)
                    
if __name__=='__main__':
    resize_image()
    store_raw_images()
    find_uglies()
    create_pos_n_neg()
# Out:
# http://static.flickr.com/16/22297113_4684e01de3.jpg
# http://farm3.static.flickr.com/2236/2133960132_fbbc45ffff.jpg
# http://farm4.static.flickr.com/3153/2632116384_c8b01ac14c.jpg
# http://upload.wikimedia.org/wikipedia/commons/5/53/Ambulance_Graz_side.jpg
# http://farm3.static.flickr.com/2306/1557946429_abdc278a06.jpg
# http://farm1.static.flickr.com/119/290391702_0177fe64e1.jpg
# http://farm3.static.flickr.com/2326/2419220011_106d0ca894.jpg
# http://farm3.static.flickr.com/2404/2059157619_c5b41eccbd.jpg
# http://nancymorgensternmemorial.org/graphics/ambulance%20pix/images/nm-ambulance%20-%2003_jpg.jpg
# http://www.stpaulfd.com/Data/Images/Ambulance%20159.jpg
# <urlopen error [Errno 11001] getaddrinfo failed>
# http://www.ukemergency.co.uk/ambulance/dsc04352.jpg
# HTTP Error 404: Not Found
# http://farm4.static.flickr.com/3083/2637614699_948431b3ee.jpg
# http://farm3.static.flickr.com/2412/2463447971_e98a78a15f.jpg
# ...

# %%
def resize_image1():
    img = cv2.imread(r"C:\Users\dell\Desktop\Hemant\Images\Ambulance1.jpg")
    resized_image = cv2.resize(img, (30, 60))
    cv2.imwrite(r"C:\Users\dell\Desktop\Hemant\Images\Ambulance1.jpg",resized_image)
def store_raw_images1():
    neg_images_link = 'http://www.image-net.org/api/text/imagenet.synset.geturls?wnid=n10097842'   
    neg_image_urls = urllib.request.urlopen(neg_images_link).read().decode()
    pic_num = 1
    
    if not os.path.exists('neg'):
        os.makedirs('neg')
        
    for i in neg_image_urls.split('\n'):
        try:
            print(i)
            urllib.request.urlretrieve(i, "neg/"+str(pic_num)+".jpg")
            img = cv2.imread("neg/"+str(pic_num)+".jpg",cv2.IMREAD_GRAYSCALE)
            # should be larger than samples / pos pic (so we can place our image on it)
            resized_image = cv2.resize(img, (200, 200))
            cv2.imwrite("neg/"+str(pic_num)+".jpg",resized_image)
            pic_num += 1
            
        except Exception as e:
            print(str(e))  

def find_uglies1():
    match = False
    for file_type in ['neg']:
        for img in os.listdir(file_type):
            for ugly in os.listdir('uglies'):
                try:
                    current_image_path = str(file_type)+'/'+str(img)
                    ugly = cv2.imread('uglies/'+str(ugly))
                    question = cv2.imread(current_image_path)
                    if ugly.shape == question.shape and not(np.bitwise_xor(ugly,question).any()):
                        print('That is one ugly pic! Deleting!')
                        print(current_image_path)
                        os.remove(current_image_path)
                except Exception as e:
                    print(str(e))
def create_pos_n_neg1():
    for file_type in ['neg']:        
        for img in os.listdir(file_type):
            if file_type == 'pos':
                line = file_type+'/'+img+' 1 0 0 100 100\n'
                with open('info1.dat','a') as f:
                    f.write(line)
            elif file_type == 'neg':
                line = file_type+'/'+img+'\n'
                with open('bg1.txt','a') as f:
                    f.write(line)
                    
if __name__=='__main__':
    resize_image1()
    store_raw_images1()
    find_uglies1()
    create_pos_n_neg1()
